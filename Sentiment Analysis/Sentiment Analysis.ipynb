# %%
'''
A project completed with Udacity Deep Learning part mentored by Andrew Trask.
'''

##Part 1- Curating the dataset
file=open("reviews.txt",'r')
reviews=list(map(lambda x:x[:-1],file.readlines()))#-1 is used so the \n doesn't appear in the print
file.close
#read the labels
file=open("labels.txt",'r')
labels=list(map(lambda x:x[:-1].upper(),file.readlines()))
file.close()

# %%
def print_review_and_label(i):
    print(labels[i] +"\t:\t"+ reviews[i][:80]+"...")

# %%
import pandas as pd
import numpy as np
pd=pd.read_csv('reviews.txt',header=None)
pd.head()
# Out:
#                                                    0
# 0  bromwell high is a cartoon comedy . it ran at ...
# 1  story of a man who has unnatural feelings for ...
# 2  homelessness  or houselessness as george carli...
# 3  airport    starts as a brand new luxury    pla...
# 4  brilliant over  acting by lesley ann warren . ...

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
print_review_and_label(0)
# Out:
# POSITIVE	:	bromwell high is a cartoon comedy . it ran at the same time as some other progra...

# %%
#Developing a predictive theory that some words appear most frequently in each label than the other

# %%
from collections import Counter

# %%
#creating a counter for each label and total words

# %%
positive_counts=Counter()
negative_counts=Counter()
total_counts=Counter()

# %%
for i  in range(0,len(labels)):
    if labels[i]=='POSITIVE':
        positive_counts.update(reviews[i].split(' '))
        total_counts.update(reviews[i].split(' '))
    elif labels[i]=="NEGATIVE":
        negative_counts.update(reviews[i].split(' '))
        total_counts.update(reviews[i].split(' '))

# %%
positive_counts.most_common()
# Out:
# [('', 1100936),
#  ('the', 346648),
#  ('.', 319308),
#  ('and', 179444),
#  ('a', 167376),
#  ('of', 153710),
#  ('to', 133492),
#  ('is', 114490),
#  ('in', 100430),
#  ('br', 98470),
#  ('it', 96050),
#  ('i', 81486),
#  ('that', 71260),
#  ('this', 70160),
#  ('s', 67630),
#  ('as', 52616),
#  ('with', 46494),
#  ('for', 44832),
#  ('was', 43834),
#  ('film', 41874),
#  ('but', 41644),
#  ('movie', 38148),
#  ('his', 34454),
#  ('on', 34016),
#  ('you', 33362),
#  ('he', 32564),
#  ('are', 29614),
#  ('not', 28544),
#  ('t', 27440),
#  ('one', 27310),
#  ('have', 25174),
#  ('be', 24832),
#  ('by', 23994),
#  ('all', 23884),
#  ('who', 22928),
#  ('an', 22588),
#  ('at', 22468),
#  ('from', 21534),
#  ('her', 20948),
#  ('they', 19790),
#  ('has', 18372),
#  ('so', 18308),
#  ('like', 18076),
#  ('about', 16626),
#  ('very', 16610),
#  ('out', 16268),
#  ('there', 16114),
#  ('she', 15558),
#  ('what', 15474),
#  ('or', 15464),
#  ('good', 15440),
#  ('more', 15042),
# ...

# %%
total_counts.most_common()
# Out:
# [(' ', 7434318),
#  ('e', 3087080),
#  ('t', 2455013),
#  ('a', 2245822),
#  ('i', 2071959),
#  ('o', 1923711),
#  ('s', 1819959),
#  ('n', 1706173),
#  ('r', 1551354),
#  ('h', 1408958),
#  ('l', 1143720),
#  ('', 1111930),
#  ('d', 909550),
#  ('c', 721267),
#  ('m', 714783),
#  ('u', 688467),
#  ('.', 654384),
#  ('f', 572515),
#  ('g', 538269),
#  ('y', 533264),
#  ('b', 517062),
#  ('w', 509933),
#  ('p', 441889),
#  ('the', 336713),
#  ('v', 326832),
#  ('k', 224211),
#  ('and', 164107),
#  ('of', 145864),
#  ('to', 135720),
#  ('is', 107328),
#  ('br', 101872),
#  ('it', 96352),
#  ('in', 93968),
#  ('this', 76000),
#  ('that', 73245),
#  ('j', 59093),
#  ('was', 48208),
#  ('as', 46933),
#  ('for', 44343),
#  ('with', 44125),
#  ('movie', 44039),
#  ('x', 43714),
#  ('but', 42603),
#  ('film', 40155),
#  ('you', 34230),
#  ('on', 34200),
#  ('not', 30626),
#  ('he', 30138),
#  ('are', 29430),
#  ('his', 29374),
#  ('have', 27731),
#  ('be', 26957),
#  ('one', 26789),
# ...

# %%
#find the ratio of usage of words in positive to negative so that we can find the words used in positive count more than the nefative

# %%
pos_neg_ratios = Counter()
for i, cnt in list(total_counts.most_common()):
    if cnt>100:
        
        ratio=(positive_counts[i]/float(negative_counts[i]+1))
        pos_neg_ratios[i]=(ratio)

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.060802560752068
# Pos-to-neg ratio for 'amazing' = 4.0304761904761905
# Pos-to-neg ratio for 'terrible' = 0.17750628817822495

# %%
for i, ratio in list(pos_neg_ratios.most_common()):
    pos_neg_ratios[i]=np.log(ratio)
# Out:
# C:\Users\Siddharth\Anaconda3\envs\tensorflow-gpu\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902575442851183
# Pos-to-neg ratio for 'amazing' = 1.3938845303865663
# Pos-to-neg ratio for 'terrible' = -1.7287492443379682

# %%
#most common positive and negative words
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.3844950627890888),
#  ('paulie', 4.3652195163575005),
#  ('felix', 3.2580965380214821),
#  ('polanski', 2.9103724246028344),
#  ('matthau', 2.8638801424491884),
#  ('victoria', 2.7149230803899722),
#  ('mildred', 2.6672282065819548),
#  ('gandhi', 2.5961322848982249),
#  ('flawless', 2.5022983924998696),
#  ('superbly', 2.3025850929940459),
#  ('perfection', 2.1933858010290535),
#  ('astaire', 2.1764338076671454),
#  ('voight', 2.0693912058263346),
#  ('captures', 2.0588222544771004),
#  ('wonderfully', 2.0351412827832558),
#  ('powell', 1.9977635106655687),
#  ('brosnan', 1.9865477947871395),
#  ('lily', 1.9502298101998297),
#  ('bakshi', 1.9328380674879606),
#  ('lincoln', 1.9234372932032546),
#  ('lemmon', 1.8797282421740122),
#  ('refreshing', 1.8731998011682294),
#  ('breathtaking', 1.8700913124979619),
#  ('bourne', 1.8672670217362002),
#  ('flynn', 1.8237622003142289),
#  ('delightful', 1.8131735637318716),
#  ('homer', 1.8031881650516777),
# ...

# %%
list(reversed(pos_neg_ratios.most_common()))
# Out:
# [(' ', -inf),
#  ('boll', -4.966335035199676),
#  ('uwe', -4.6200587984818418),
#  ('seagal', -3.6408702349275757),
#  ('unwatchable', -3.253277251585533),
#  ('stinker', -3.2037621870581527),
#  ('mst', -2.9473586892697754),
#  ('incoherent', -2.9330967025625059),
#  ('unfunny', -2.6902455764687034),
#  ('waste', -2.6190165787318125),
#  ('blah', -2.5676928434072877),
#  ('horrid', -2.4802662702314979),
#  ('pointless', -2.4542326426031855),
#  ('atrocious', -2.4231420555331544),
#  ('redeeming', -2.3665654226574531),
#  ('prom', -2.3561258599220758),
#  ('drivel', -2.3426795501959239),
#  ('lousy', -2.3050819731926326),
#  ('worst', -2.2867863442296801),
#  ('laughable', -2.2630643348317623),
#  ('awful', -2.2268732712583494),
#  ('poorly', -2.2199795803298832),
#  ('wasting', -2.2009214392175456),
#  ('remotely', -2.1942963175571308),
#  ('existent', -2.075963277303511),
#  ('boredom', -1.9910923718485463),
#  ('miserably', -1.9878743481543455),
#  ('sucks', -1.9850500573925836),
# ...
